# %% [markdown]
# # ETL of Emission and Population Data

# %%
#Boto3 is the AWS Software Development Kit for Python
# %pip install boto3
# Out:
# Requirement already satisfied: boto3 in c:\users\pravi\anaconda3\envs\pythondata\lib\site-packages (1.20.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\pravi\anaconda3\envs\pythondata\lib\site-packages (from boto3) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\pravi\anaconda3\envs\pythondata\lib\site-packages (from boto3) (0.5.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.4 in c:\users\pravi\anaconda3\envs\pythondata\lib\site-packages (from boto3) (1.23.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\pravi\anaconda3\envs\pythondata\lib\site-packages (from botocore<1.24.0,>=1.23.4->boto3) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\pravi\anaconda3\envs\pythondata\lib\site-packages (from botocore<1.24.0,>=1.23.4->boto3) (1.26.4)
# Requirement already satisfied: six>=1.5 in c:\users\pravi\anaconda3\envs\pythondata\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.24.0,>=1.23.4->boto3) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import dependencies
import pandas as pd 
import os 
import csv 
import numpy as np 
from sqlalchemy import create_engine, inspect
import boto3
from io import StringIO

# %% [markdown]
# # Emission Data Cleaning

# %%
# 1. Create a DataFrame for the Emission data
emissions_data_df=pd.read_csv('Emissions_Data.csv',low_memory=False)
emissions_data_df.head()
# Out:
#    Area Code         Area  Item Code                  Item  Element Code  \
# 0          2  Afghanistan       5058  Enteric Fermentation          7225
# 1          2  Afghanistan       5058  Enteric Fermentation          7225
# 2          2  Afghanistan       5058  Enteric Fermentation        724413
# 3          2  Afghanistan       5058  Enteric Fermentation        724413
# 4          2  Afghanistan       5058  Enteric Fermentation        723113
#
#                             Element  Source Code      Source        Unit  \
# 0                   Emissions (CH4)         3050  FAO TIER 1  kilotonnes
# 1                   Emissions (CH4)         3051      UNFCCC  kilotonnes
# 2  Emissions (CO2eq) from CH4 (AR5)         3050  FAO TIER 1  kilotonnes
# 3  Emissions (CO2eq) from CH4 (AR5)         3051      UNFCCC  kilotonnes
# 4           Emissions (CO2eq) (AR5)         3050  FAO TIER 1  kilotonnes
#
#        Y1961  ... Y2016N       Y2017  Y2017F Y2017N       Y2018  Y2018F  \
# 0   240.6831  ...    NaN    371.2863      Fc    NaN    378.8870      Fc
# 1        NaN  ...    NaN         NaN     NaN    NaN         NaN     NaN
# 2  6739.1279  ...    NaN  10396.0163      Fc    NaN  10608.8357      Fc
# 3        NaN  ...    NaN         NaN     NaN    NaN         NaN     NaN
# 4  6739.1279  ...    NaN  10396.0163      Fc    NaN  10608.8357      Fc
#
#   Y2018N       Y2019  Y2019F Y2019N
# 0    NaN    389.6563      Fc    NaN
# 1    NaN         NaN     NaN    NaN
# 2    NaN  10910.3754      Fc    NaN
# 3    NaN         NaN     NaN    NaN
# 4    NaN  10910.3754      Fc    NaN
#
# [5 rows x 186 columns]

# %%
# 2. Check the datatypes of your columns. 
emissions_data_df.dtypes
# Out:
# Area Code         int64
# Area             object
# Item Code         int64
# Item             object
# Element Code      int64
#                  ...
# Y2018F           object
# Y2018N           object
# Y2019           float64
# Y2019F           object
# Y2019N           object
# Length: 186, dtype: object

# %%
#display the columns
emissions_data_df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Source Code', 'Source', 'Unit', 'Y1961',
#        ...
#        'Y2016N', 'Y2017', 'Y2017F', 'Y2017N', 'Y2018', 'Y2018F', 'Y2018N',
#        'Y2019', 'Y2019F', 'Y2019N'],
#       dtype='object', length=186)

# %%
# Row count
emissions_data_df.count()
# Out:
# Area Code       35214
# Area            35214
# Item Code       35214
# Item            35214
# Element Code    35214
#                 ...
# Y2018F          30501
# Y2018N            214
# Y2019           31349
# Y2019F          30475
# Y2019N            210
# Length: 186, dtype: int64

# %%
# Finding Mean,Std,Min,Max etc.
emissions_data_df.describe().T
# Out:
#                 count           mean            std          min          25%  \
# Area Code     35214.0     836.225450    1802.568667        1.000    75.000000
# Item Code     35214.0    9323.758193   15686.892075     1707.000  5059.000000
# Element Code  35214.0  365351.316976  358303.088068     7225.000  7230.000000
# Source Code   35214.0    3050.142727       0.349800     3050.000  3050.000000
# Y1961          9695.0    9248.883169   76293.922762        0.000     0.405600
# ...               ...            ...            ...          ...          ...
# Y2015         31649.0   18766.775147  205781.535921 -3966552.558     0.038000
# Y2016         31578.0   18789.611363  191236.770842 -2720180.973     0.035700
# Y2017         31414.0   18796.475622  191542.218907 -2636985.222     0.037925
# Y2018         31390.0   19024.886269  193904.479619 -2636985.222     0.033550
# Y2019         31349.0   19472.867850  197601.979147 -2636985.222     0.038700
#
#                      50%            75%           max
# Area Code      150.00000     223.000000  5.873000e+03
# Item Code     5066.00000    6993.000000  6.992100e+04
# Element Code  7273.00000  724313.000000  7.244130e+05
# Source Code   3050.00000    3050.000000  3.051000e+03
# Y1961           11.29130     345.274500  3.261482e+06
# ...                  ...            ...           ...
# Y2015           10.21410     667.864100  1.111916e+07
# Y2016           10.68550     669.740275  1.029408e+07
# Y2017           10.31540     658.084100  1.034031e+07
# Y2018            9.92465     653.896400  1.048629e+07
# Y2019           10.51110     668.331500  1.071663e+07
#
# [92 rows x 8 columns]

# %%
emissions_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35214 entries, 0 to 35213
# Columns: 186 entries, Area Code to Y2019N
# dtypes: float64(88), int64(4), object(94)
# memory usage: 50.0+ MB

# %%
emissions_data_df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Source Code', 'Source', 'Unit', 'Y1961',
#        ...
#        'Y2016N', 'Y2017', 'Y2017F', 'Y2017N', 'Y2018', 'Y2018F', 'Y2018N',
#        'Y2019', 'Y2019F', 'Y2019N'],
#       dtype='object', length=186)

# %%
#checking for null values
emissions_data_df.isnull()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element  Source Code  \
# 0          False  False      False  False         False    False        False
# 1          False  False      False  False         False    False        False
# 2          False  False      False  False         False    False        False
# 3          False  False      False  False         False    False        False
# 4          False  False      False  False         False    False        False
# ...          ...    ...        ...    ...           ...      ...          ...
# 35209      False  False      False  False         False    False        False
# 35210      False  False      False  False         False    False        False
# 35211      False  False      False  False         False    False        False
# 35212      False  False      False  False         False    False        False
# 35213      False  False      False  False         False    False        False
#
#        Source   Unit  Y1961  ...  Y2016N  Y2017  Y2017F  Y2017N  Y2018  \
# 0       False  False  False  ...    True  False   False    True  False
# 1       False  False   True  ...    True   True    True    True   True
# 2       False  False  False  ...    True  False   False    True  False
# 3       False  False   True  ...    True   True    True    True   True
# 4       False  False  False  ...    True  False   False    True  False
# ...       ...    ...    ...  ...     ...    ...     ...     ...    ...
# 35209   False  False   True  ...    True  False   False    True  False
# 35210   False  False   True  ...    True  False   False    True  False
# 35211   False  False   True  ...    True  False   False    True  False
# 35212   False  False   True  ...    True  False   False    True  False
# 35213   False  False   True  ...    True  False   False    True  False
#
#        Y2018F  Y2018N  Y2019  Y2019F  Y2019N
# 0       False    True  False   False    True
# 1        True    True   True    True    True
# 2       False    True  False   False    True
# 3        True    True   True    True    True
# 4       False    True  False   False    True
# ...       ...     ...    ...     ...     ...
# 35209   False    True  False   False    True
# 35210   False    True  False   False    True
# 35211   False    True  False   False    True
# 35212   False    True  False   False    True
# 35213   False    True  False   False    True
#
# [35214 rows x 186 columns]

# %%
#Sum of null values
emissions_data_df.isnull().sum()
# Out:
# Area Code           0
# Area                0
# Item Code           0
# Item                0
# Element Code        0
#                 ...
# Y2018F           4713
# Y2018N          35000
# Y2019            3865
# Y2019F           4739
# Y2019N          35004
# Length: 186, dtype: int64

# %%
#Check for unique values
emissions_data_df.nunique().tolist()
# Out:
# [281,
#  281,
#  25,
#  25,
#  8,
#  8,
#  2,
#  2,
#  1,
#  6777,
#  1,
#  0,
#  6809,
#  1,
#  0,
#  6811,
#  1,
#  0,
#  6851,
#  1,
#  0,
#  6825,
#  1,
#  0,
#  6855,
#  1,
#  0,
#  6875,
#  1,
#  0,
#  6901,
#  1,
#  0,
#  6887,
#  1,
#  0,
#  6931,
#  1,
#  0,
#  6949,
#  1,
#  0,
#  6963,
#  1,
#  0,
#  6971,
#  1,
#  0,
#  6987,
#  1,
#  0,
#  6959,
#  1,
#  0,
#  6983,
#  1,
#  0,
#  6987,
#  1,
#  0,
#  6994,
#  1,
#  0,
#  7032,
#  1,
#  0,
#  7031,
#  1,
#  0,
#  7053,
#  1,
#  0,
#  7052,
#  1,
#  0,
#  7049,
#  1,
#  0,
#  7053,
#  1,
#  0,
#  7080,
#  1,
#  0,
#  7078,
#  1,
#  0,
#  7072,
#  1,
#  0,
#  7069,
#  1,
#  0,
#  7095,
#  1,
#  0,
#  15728,
#  2,
#  2,
#  15524,
#  2,
#  2,
#  16989,
#  2,
#  2,
#  17212,
#  2,
#  2,
#  18013,
#  2,
#  2,
#  17292,
#  2,
#  2,
#  17053,
#  2,
#  2,
#  17148,
#  2,
#  2,
#  17180,
#  2,
#  2,
#  17147,
#  2,
#  2,
#  18053,
#  2,
#  2,
#  16588,
#  2,
#  2,
#  16739,
#  2,
#  2,
#  16907,
#  2,
#  2,
#  16824,
#  2,
#  2,
#  17061,
#  2,
#  2,
#  16949,
#  2,
#  2,
#  16994,
#  2,
#  2,
#  16796,
#  2,
#  2,
#  16867,
#  2,
#  2,
#  17223,
#  2,
#  2,
#  16796,
#  2,
#  2,
#  17059,
#  2,
#  2,
#  16834,
#  2,
#  2,
#  16850,
#  2,
#  2,
#  16859,
#  2,
#  2,
#  16655,
#  2,
#  2,
#  16623,
#  2,
#  2,
#  16491,
#  1,
#  1,
#  16603,
#  1,
#  1]

# %%
#Listing unique countries
countries=emissions_data_df['Area'].unique()
countries
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belgium-Luxembourg', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, mainland', 'China, Taiwan Province of',
#        'Colombia', 'Comoros', 'Congo', 'Cook Islands', 'Costa Rica',
#        "C�te d'Ivoire", 'Croatia', 'Cuba', 'Cyprus', 'Czechia',
#        'Czechoslovakia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR',
#        'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland',
#        'France', 'French Guyana', 'French Polynesia', 'Gabon', 'Gambia',
#        'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
#        'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'Holy See', 'Honduras',
#        'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran (Islamic Republic of)', 'Iraq', 'Ireland', 'Isle of Man',
#        'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kiribati', 'Kuwait', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius',
#        'Mayotte', 'Mexico', 'Micronesia (Federated States of)', 'Monaco',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'Netherlands Antilles (former)', 'New Caledonia', 'New Zealand',
#        'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island',
#        'North Macedonia', 'Northern Mariana Islands', 'Norway', 'Oman',
#        'Pacific Islands Trust Territory', 'Pakistan', 'Palau',
#        'Palestine', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico',
#        'Qatar', 'Republic of Korea', 'Republic of Moldova', 'R�union',
#        'Romania', 'Russian Federation', 'Rwanda',
#        'Saint Helena, Ascension and Tristan da Cunha',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Serbia and Montenegro', 'Seychelles',
#        'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
#        'Spain', 'Sri Lanka', 'Sudan', 'Sudan (former)', 'Suriname',
#        'Svalbard and Jan Mayen Islands', 'Sweden', 'Switzerland',
#        'Syrian Arab Republic', 'Tajikistan', 'Thailand', 'Timor-Leste',
#        'Togo', 'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia',
#        'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
#        'Uganda', 'Ukraine', 'United Arab Emirates',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United Republic of Tanzania', 'United States of America',
#        'United States Virgin Islands', 'Uruguay', 'USSR', 'Uzbekistan',
#        'Vanuatu', 'Venezuela (Bolivarian Republic of)', 'Viet Nam',
#        'Wallis and Futuna Islands', 'Western Sahara', 'Yemen',
#        'Yugoslav SFR', 'Zambia', 'Zimbabwe', 'World', 'Africa',
#        'Eastern Africa', 'Middle Africa', 'Northern Africa',
#        'Southern Africa', 'Western Africa', 'Americas',
#        'Northern America', 'Central America', 'Caribbean',
#        'South America', 'Asia', 'Central Asia', 'Eastern Asia',
#        'Southern Asia', 'South-eastern Asia', 'Western Asia', 'Europe',
#        'Eastern Europe', 'Northern Europe', 'Southern Europe',
#        'Western Europe', 'Oceania', 'Australia and New Zealand',
#        'Melanesia', 'Micronesia', 'Polynesia', 'European Union (28)',
#        'European Union (27)', 'Least Developed Countries',
#        'Land Locked Developing Countries',
#        'Small Island Developing States',
#        'Low Income Food Deficit Countries',
#        'Net Food Importing Developing Countries', 'Annex I countries',
#        'Non-Annex I countries', 'OECD'], dtype=object)

# %%
#listing unique items
items=emissions_data_df['Item'].unique()
items
# Out:
# array(['Enteric Fermentation', 'Manure Management', 'Rice Cultivation',
#        'Synthetic Fertilizers', 'Manure applied to Soils',
#        'Manure left on Pasture', 'Crop Residues',
#        'Burning - Crop residues', 'Net Forest conversion', 'Forestland',
#        'Savanna fires', 'Fires in humid tropical forests', 'Forest fires',
#        'Fires in organic soils', 'On-farm energy use', 'IPCC Agriculture',
#        'Agricultural Soils', 'LULUCF', 'AFOLU',
#        'Emissions on agricultural land', 'Farm-gate emissions',
#        'Land Use change', 'Drained organic soils',
#        'Drained organic soils (CO2)', 'Drained organic soils (N2O)'],
#       dtype=object)

# %%
#listing unique elements
elements=emissions_data_df['Element'].unique()
items
# Out:
# array(['Enteric Fermentation', 'Manure Management', 'Rice Cultivation',
#        'Synthetic Fertilizers', 'Manure applied to Soils',
#        'Manure left on Pasture', 'Crop Residues',
#        'Burning - Crop residues', 'Net Forest conversion', 'Forestland',
#        'Savanna fires', 'Fires in humid tropical forests', 'Forest fires',
#        'Fires in organic soils', 'On-farm energy use', 'IPCC Agriculture',
#        'Agricultural Soils', 'LULUCF', 'AFOLU',
#        'Emissions on agricultural land', 'Farm-gate emissions',
#        'Land Use change', 'Drained organic soils',
#        'Drained organic soils (CO2)', 'Drained organic soils (N2O)'],
#       dtype=object)

# %%
#Store and Display unique source and source code
source_code=emissions_data_df['Source Code'].unique()
source=emissions_data_df['Source'].unique()
print(source_code)
print(source)
# Out:
# [3050 3051]
# ['FAO TIER 1' 'UNFCCC']

# %%
#Checking for the row values for Source Code = 3051
emissions_data_df.loc[(emissions_data_df['Source Code'])==3051]
# Out:
#        Area Code                   Area  Item Code                  Item  \
# 1              2            Afghanistan       5058  Enteric Fermentation
# 3              2            Afghanistan       5058  Enteric Fermentation
# 5              2            Afghanistan       5058  Enteric Fermentation
# 7              2            Afghanistan       5059     Manure Management
# 10             2            Afghanistan       5059     Manure Management
# ...          ...                    ...        ...                   ...
# 35051       5849  Non-Annex I countries       1709    Agricultural Soils
# 35053       5849  Non-Annex I countries       1709    Agricultural Soils
# 35054       5849  Non-Annex I countries       1709    Agricultural Soils
# 35056       5849  Non-Annex I countries       1709    Agricultural Soils
# 35058       5849  Non-Annex I countries       1709    Agricultural Soils
#
#        Element Code                           Element  Source Code  Source  \
# 1              7225                   Emissions (CH4)         3051  UNFCCC
# 3            724413  Emissions (CO2eq) from CH4 (AR5)         3051  UNFCCC
# 5            723113           Emissions (CO2eq) (AR5)         3051  UNFCCC
# 7              7225                   Emissions (CH4)         3051  UNFCCC
# 10           724413  Emissions (CO2eq) from CH4 (AR5)         3051  UNFCCC
# ...             ...                               ...          ...     ...
# 35051          7236          Indirect emissions (N2O)         3051  UNFCCC
# 35053          7230                   Emissions (N2O)         3051  UNFCCC
# 35054        724413  Emissions (CO2eq) from CH4 (AR5)         3051  UNFCCC
# 35056        724313  Emissions (CO2eq) from N2O (AR5)         3051  UNFCCC
# 35058        723113           Emissions (CO2eq) (AR5)         3051  UNFCCC
#
#              Unit  Y1961  ... Y2016N     Y2017  Y2017F Y2017N     Y2018  \
# 1      kilotonnes    NaN  ...    NaN       NaN     NaN    NaN       NaN
# 3      kilotonnes    NaN  ...    NaN       NaN     NaN    NaN       NaN
# 5      kilotonnes    NaN  ...    NaN       NaN     NaN    NaN       NaN
# 7      kilotonnes    NaN  ...    NaN       NaN     NaN    NaN       NaN
# 10     kilotonnes    NaN  ...    NaN       NaN     NaN    NaN       NaN
# ...           ...    ...  ...    ...       ...     ...    ...       ...
# 35051  kilotonnes    NaN  ...    NaN      4.79      Fc    NaN      4.89
# 35053  kilotonnes    NaN  ...    NaN     91.28      Fc    NaN     58.44
# 35054  kilotonnes    NaN  ...    NaN       NaN     NaN    NaN       NaN
# 35056  kilotonnes    NaN  ...    NaN  24189.20      Fc    NaN  15486.60
# 35058  kilotonnes    NaN  ...    NaN  24189.20      Fc    NaN  15486.60
#
#        Y2018F Y2018N     Y2019  Y2019F Y2019N
# 1         NaN    NaN       NaN     NaN    NaN
# 3         NaN    NaN       NaN     NaN    NaN
# 5         NaN    NaN       NaN     NaN    NaN
# 7         NaN    NaN       NaN     NaN    NaN
# 10        NaN    NaN       NaN     NaN    NaN
# ...       ...    ...       ...     ...    ...
# 35051      Fc    NaN      4.89      Fc    NaN
# 35053      Fc    NaN     42.20      Fc    NaN
# 35054     NaN    NaN       NaN     NaN    NaN
# 35056      Fc    NaN  11183.00      Fc    NaN
# 35058      Fc    NaN  11183.00      Fc    NaN
#
# [5026 rows x 186 columns]

# %%
# Deleting the rows with Source Code=3051 as it has more null values
emissions_data_df.drop(emissions_data_df.index[emissions_data_df['Source Code'] == 3051], inplace=True)
emissions_data_df.head(50)
# Out:
#     Area Code         Area  Item Code                             Item  \
# 0           2  Afghanistan       5058             Enteric Fermentation
# 2           2  Afghanistan       5058             Enteric Fermentation
# 4           2  Afghanistan       5058             Enteric Fermentation
# 6           2  Afghanistan       5059                Manure Management
# 8           2  Afghanistan       5059                Manure Management
# 9           2  Afghanistan       5059                Manure Management
# 11          2  Afghanistan       5059                Manure Management
# 12          2  Afghanistan       5059                Manure Management
# 14          2  Afghanistan       5060                 Rice Cultivation
# 15          2  Afghanistan       5060                 Rice Cultivation
# 16          2  Afghanistan       5060                 Rice Cultivation
# 17          2  Afghanistan       5061            Synthetic Fertilizers
# 18          2  Afghanistan       5061            Synthetic Fertilizers
# 19          2  Afghanistan       5061            Synthetic Fertilizers
# 20          2  Afghanistan       5061            Synthetic Fertilizers
# 21          2  Afghanistan       5061            Synthetic Fertilizers
# 22          2  Afghanistan       5062          Manure applied to Soils
# 23          2  Afghanistan       5062          Manure applied to Soils
# 24          2  Afghanistan       5062          Manure applied to Soils
# 25          2  Afghanistan       5062          Manure applied to Soils
# 26          2  Afghanistan       5062          Manure applied to Soils
# 27          2  Afghanistan       5063           Manure left on Pasture
# 28          2  Afghanistan       5063           Manure left on Pasture
# 29          2  Afghanistan       5063           Manure left on Pasture
# 30          2  Afghanistan       5063           Manure left on Pasture
# 31          2  Afghanistan       5063           Manure left on Pasture
# 32          2  Afghanistan       5064                    Crop Residues
# 33          2  Afghanistan       5064                    Crop Residues
# 34          2  Afghanistan       5064                    Crop Residues
# 35          2  Afghanistan       5064                    Crop Residues
# 36          2  Afghanistan       5064                    Crop Residues
# 37          2  Afghanistan       5066          Burning - Crop residues
# 39          2  Afghanistan       5066          Burning - Crop residues
# 41          2  Afghanistan       5066          Burning - Crop residues
# 43          2  Afghanistan       5066          Burning - Crop residues
# 45          2  Afghanistan       5066          Burning - Crop residues
# 47          2  Afghanistan       6750            Net Forest conversion
# 48          2  Afghanistan       6750            Net Forest conversion
# 49          2  Afghanistan       6751                       Forestland
# 50          2  Afghanistan       6751                       Forestland
# 51          2  Afghanistan       6795                    Savanna fires
# 52          2  Afghanistan       6795                    Savanna fires
# 53          2  Afghanistan       6795                    Savanna fires
# 54          2  Afghanistan       6795                    Savanna fires
# 55          2  Afghanistan       6795                    Savanna fires
# 56          2  Afghanistan      69921  Fires in humid tropical forests
# 57          2  Afghanistan      69921  Fires in humid tropical forests
# 58          2  Afghanistan      69921  Fires in humid tropical forests
# 59          2  Afghanistan      69921  Fires in humid tropical forests
# 60          2  Afghanistan      69921  Fires in humid tropical forests
#
#     Element Code                           Element  Source Code      Source  \
# 0           7225                   Emissions (CH4)         3050  FAO TIER 1
# 2         724413  Emissions (CO2eq) from CH4 (AR5)         3050  FAO TIER 1
# 4         723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 6           7225                   Emissions (CH4)         3050  FAO TIER 1
# 8           7230                   Emissions (N2O)         3050  FAO TIER 1
# 9         724413  Emissions (CO2eq) from CH4 (AR5)         3050  FAO TIER 1
# 11        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# 12        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 14          7225                   Emissions (CH4)         3050  FAO TIER 1
# 15        724413  Emissions (CO2eq) from CH4 (AR5)         3050  FAO TIER 1
# 16        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 17          7234            Direct emissions (N2O)         3050  FAO TIER 1
# 18          7236          Indirect emissions (N2O)         3050  FAO TIER 1
# 19          7230                   Emissions (N2O)         3050  FAO TIER 1
# 20        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# 21        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 22          7234            Direct emissions (N2O)         3050  FAO TIER 1
# 23          7236          Indirect emissions (N2O)         3050  FAO TIER 1
# 24          7230                   Emissions (N2O)         3050  FAO TIER 1
# 25        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# 26        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 27          7234            Direct emissions (N2O)         3050  FAO TIER 1
# 28          7236          Indirect emissions (N2O)         3050  FAO TIER 1
# 29          7230                   Emissions (N2O)         3050  FAO TIER 1
# 30        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# 31        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 32          7234            Direct emissions (N2O)         3050  FAO TIER 1
# 33          7236          Indirect emissions (N2O)         3050  FAO TIER 1
# 34          7230                   Emissions (N2O)         3050  FAO TIER 1
# 35        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# 36        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 37          7225                   Emissions (CH4)         3050  FAO TIER 1
# 39          7230                   Emissions (N2O)         3050  FAO TIER 1
# 41        724413  Emissions (CO2eq) from CH4 (AR5)         3050  FAO TIER 1
# 43        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# 45        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 47          7273                   Emissions (CO2)         3050  FAO TIER 1
# 48        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 49          7273                   Emissions (CO2)         3050  FAO TIER 1
# 50        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 51          7225                   Emissions (CH4)         3050  FAO TIER 1
# 52          7230                   Emissions (N2O)         3050  FAO TIER 1
# 53        724413  Emissions (CO2eq) from CH4 (AR5)         3050  FAO TIER 1
# 54        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# 55        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
# 56          7225                   Emissions (CH4)         3050  FAO TIER 1
# 57          7230                   Emissions (N2O)         3050  FAO TIER 1
# 58        724413  Emissions (CO2eq) from CH4 (AR5)         3050  FAO TIER 1
# 59        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# 60        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
#
#           Unit      Y1961  ... Y2016N       Y2017  Y2017F Y2017N       Y2018  \
# 0   kilotonnes   240.6831  ...    NaN    371.2863      Fc    NaN    378.8870
# 2   kilotonnes  6739.1279  ...    NaN  10396.0163      Fc    NaN  10608.8357
# 4   kilotonnes  6739.1279  ...    NaN  10396.0163      Fc    NaN  10608.8357
# 6   kilotonnes    11.6228  ...    NaN     23.7001      Fc    NaN     24.2499
# 8   kilotonnes     0.3992  ...    NaN      0.4013      Fc    NaN      0.4074
# 9   kilotonnes   325.4372  ...    NaN    663.6019      Fc    NaN    678.9958
# 11  kilotonnes   105.7889  ...    NaN    106.3426      Fc    NaN    107.9690
# 12  kilotonnes   431.2261  ...    NaN    769.9445      Fc    NaN    786.9648
# 14  kilotonnes    29.4000  ...    NaN     15.3233      Fc    NaN     16.4555
# 15  kilotonnes   823.2000  ...    NaN    429.0518      Fc    NaN    460.7529
# 16  kilotonnes   823.2000  ...    NaN    429.0518      Fc    NaN    460.7529
# 17  kilotonnes     0.0157  ...    NaN      2.2122      Fc    NaN      0.7325
# 18  kilotonnes     0.0051  ...    NaN      0.7190      Fc    NaN      0.2381
# 19  kilotonnes     0.0208  ...    NaN      2.9312      Fc    NaN      0.9706
# 20  kilotonnes     5.5177  ...    NaN    776.7559      Fc    NaN    257.1983
# 21  kilotonnes     5.5177  ...    NaN    776.7559      Fc    NaN    257.1983
# 22  kilotonnes     0.8839  ...    NaN      1.1196      Fc    NaN      1.1396
# 23  kilotonnes     0.3756  ...    NaN      0.4758      Fc    NaN      0.4843
# 24  kilotonnes     1.2595  ...    NaN      1.5955      Fc    NaN      1.6240
# 25  kilotonnes   333.7651  ...    NaN    422.8019      Fc    NaN    430.3540
# 26  kilotonnes   333.7651  ...    NaN    422.8019      Fc    NaN    430.3540
# 27  kilotonnes     5.5154  ...    NaN      7.5636      Fc    NaN      7.7016
# 28  kilotonnes     2.1238  ...    NaN      2.5633      Fc    NaN      2.6057
# 29  kilotonnes     7.6393  ...    NaN     10.1269      Fc    NaN     10.3073
# 30  kilotonnes  2024.4063  ...    NaN   2683.6340      Fc    NaN   2731.4381
# 31  kilotonnes  2024.4063  ...    NaN   2683.6340      Fc    NaN   2731.4381
# 32  kilotonnes     0.8762  ...    NaN      1.0615      Fc    NaN      0.8988
# 33  kilotonnes     0.1972  ...    NaN      0.2388      Fc    NaN      0.2022
# 34  kilotonnes     1.0734  ...    NaN      1.3004      Fc    NaN      1.1010
# 35  kilotonnes   284.4486  ...    NaN    344.6049      Fc    NaN    291.7622
# 36  kilotonnes   284.4486  ...    NaN    344.6049      Fc    NaN    291.7622
# 37  kilotonnes     4.0734  ...    NaN      2.7997      Fc    NaN      2.1390
# 39  kilotonnes     0.1056  ...    NaN      0.0726      Fc    NaN      0.0555
# 41  kilotonnes   114.0555  ...    NaN     78.3910      Fc    NaN     59.8924
# 43  kilotonnes    27.9858  ...    NaN     19.2348      Fc    NaN     14.6958
# 45  kilotonnes   142.0413  ...    NaN     97.6259      Fc    NaN     74.5882
# 47  kilotonnes        NaN  ...    NaN      0.0000      Fc    NaN      0.0000
# 48  kilotonnes        NaN  ...    NaN      0.0000      Fc    NaN      0.0000
# 49  kilotonnes        NaN  ...    NaN    154.6574      Fc    NaN    154.6574
# 50  kilotonnes        NaN  ...    NaN    154.6574      Fc    NaN    154.6574
# 51  kilotonnes        NaN  ...    NaN      0.0077      Fc    NaN      0.0038
# 52  kilotonnes        NaN  ...    NaN      0.0007      Fc    NaN      0.0004
# 53  kilotonnes        NaN  ...    NaN      0.2154      Fc    NaN      0.1077
# 54  kilotonnes        NaN  ...    NaN      0.1861      Fc    NaN      0.0931
# 55  kilotonnes        NaN  ...    NaN      0.4015      Fc    NaN      0.2008
# 56  kilotonnes        NaN  ...    NaN      0.0000      Fc    NaN      0.0000
# 57  kilotonnes        NaN  ...    NaN      0.0000      Fc    NaN      0.0000
# 58  kilotonnes        NaN  ...    NaN      0.0000      Fc    NaN      0.0000
# 59  kilotonnes        NaN  ...    NaN      0.0000      Fc    NaN      0.0000
# 60  kilotonnes        NaN  ...    NaN      0.0000      Fc    NaN      0.0000
#
#     Y2018F Y2018N       Y2019  Y2019F Y2019N
# 0       Fc    NaN    389.6563      Fc    NaN
# 2       Fc    NaN  10910.3754      Fc    NaN
# 4       Fc    NaN  10910.3754      Fc    NaN
# 6       Fc    NaN     26.1252      Fc    NaN
# 8       Fc    NaN      0.3654      Fc    NaN
# 9       Fc    NaN    731.5053      Fc    NaN
# 11      Fc    NaN     96.8220      Fc    NaN
# 12      Fc    NaN    828.3273      Fc    NaN
# 14      Fc    NaN     17.8542      Fc    NaN
# 15      Fc    NaN    499.9176      Fc    NaN
# 16      Fc    NaN    499.9176      Fc    NaN
# 17      Fc    NaN      1.4879      Fc    NaN
# 18      Fc    NaN      0.4836      Fc    NaN
# 19      Fc    NaN      1.9715      Fc    NaN
# 20      Fc    NaN    522.4510      Fc    NaN
# 21      Fc    NaN    522.4510      Fc    NaN
# 22      Fc    NaN      1.0882      Fc    NaN
# 23      Fc    NaN      0.4625      Fc    NaN
# 24      Fc    NaN      1.5507      Fc    NaN
# 25      Fc    NaN    410.9284      Fc    NaN
# 26      Fc    NaN    410.9284      Fc    NaN
# 27      Fc    NaN      7.5701      Fc    NaN
# 28      Fc    NaN      2.4844      Fc    NaN
# 29      Fc    NaN     10.0545      Fc    NaN
# 30      Fc    NaN   2664.4412      Fc    NaN
# 31      Fc    NaN   2664.4412      Fc    NaN
# 32      Fc    NaN      1.2176      Fc    NaN
# 33      Fc    NaN      0.2740      Fc    NaN
# 34      Fc    NaN      1.4916      Fc    NaN
# 35      Fc    NaN    395.2689      Fc    NaN
# 36      Fc    NaN    395.2689      Fc    NaN
# 37      Fc    NaN      2.9693      Fc    NaN
# 39      Fc    NaN      0.0770      Fc    NaN
# 41      Fc    NaN     83.1393      Fc    NaN
# 43      Fc    NaN     20.3999      Fc    NaN
# 45      Fc    NaN    103.5392      Fc    NaN
# 47      Fc    NaN      0.0000      Fc    NaN
# 48      Fc    NaN      0.0000      Fc    NaN
# 49      Fc    NaN    154.6574      Fc    NaN
# 50      Fc    NaN    154.6574      Fc    NaN
# 51      Fc    NaN      0.1432      Fc    NaN
# 52      Fc    NaN      0.0131      Fc    NaN
# 53      Fc    NaN      4.0089      Fc    NaN
# 54      Fc    NaN      3.4642      Fc    NaN
# 55      Fc    NaN      7.4730      Fc    NaN
# 56      Fc    NaN      0.0000      Fc    NaN
# 57      Fc    NaN      0.0000      Fc    NaN
# 58      Fc    NaN      0.0000      Fc    NaN
# 59      Fc    NaN      0.0000      Fc    NaN
# 60      Fc    NaN      0.0000      Fc    NaN
#
# [50 rows x 186 columns]

# %%
x=emissions_data_df.groupby(['Source Code']).count()['Y1979']
x
# Out:
# Source Code
# 3050    9852
# Name: Y1979, dtype: int64

# %%
#Checking the data for Source Code=3050
emissions_data_df.loc[emissions_data_df['Source Code'] == 3050]
# Out:
#        Area Code         Area  Item Code                  Item  Element Code  \
# 0              2  Afghanistan       5058  Enteric Fermentation          7225
# 2              2  Afghanistan       5058  Enteric Fermentation        724413
# 4              2  Afghanistan       5058  Enteric Fermentation        723113
# 6              2  Afghanistan       5059     Manure Management          7225
# 8              2  Afghanistan       5059     Manure Management          7230
# ...          ...          ...        ...                   ...           ...
# 35209       5873         OECD       6516       Land Use change          7230
# 35210       5873         OECD       6516       Land Use change          7273
# 35211       5873         OECD       6516       Land Use change        724413
# 35212       5873         OECD       6516       Land Use change        724313
# 35213       5873         OECD       6516       Land Use change        723113
#
#                                 Element  Source Code      Source        Unit  \
# 0                       Emissions (CH4)         3050  FAO TIER 1  kilotonnes
# 2      Emissions (CO2eq) from CH4 (AR5)         3050  FAO TIER 1  kilotonnes
# 4               Emissions (CO2eq) (AR5)         3050  FAO TIER 1  kilotonnes
# 6                       Emissions (CH4)         3050  FAO TIER 1  kilotonnes
# 8                       Emissions (N2O)         3050  FAO TIER 1  kilotonnes
# ...                                 ...          ...         ...         ...
# 35209                   Emissions (N2O)         3050  FAO TIER 1  kilotonnes
# 35210                   Emissions (CO2)         3050  FAO TIER 1  kilotonnes
# 35211  Emissions (CO2eq) from CH4 (AR5)         3050  FAO TIER 1  kilotonnes
# 35212  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1  kilotonnes
# 35213           Emissions (CO2eq) (AR5)         3050  FAO TIER 1  kilotonnes
#
#            Y1961  ... Y2016N        Y2017  Y2017F Y2017N        Y2018  Y2018F  \
# 0       240.6831  ...    NaN     371.2863      Fc    NaN     378.8870      Fc
# 2      6739.1279  ...    NaN   10396.0163      Fc    NaN   10608.8357      Fc
# 4      6739.1279  ...    NaN   10396.0163      Fc    NaN   10608.8357      Fc
# 6        11.6228  ...    NaN      23.7001      Fc    NaN      24.2499      Fc
# 8         0.3992  ...    NaN       0.4013      Fc    NaN       0.4074      Fc
# ...          ...  ...    ...          ...     ...    ...          ...     ...
# 35209        NaN  ...    NaN       0.7522      Fc    NaN       0.9253      Fc
# 35210        NaN  ...    NaN  209078.1221      Fc    NaN  209078.1221      Fc
# 35211        NaN  ...    NaN     230.6636      Fc    NaN     283.7454      Fc
# 35212        NaN  ...    NaN     199.3235      Fc    NaN     245.1931      Fc
# 35213        NaN  ...    NaN  209508.1091      Fc    NaN  209607.0606      Fc
#
#       Y2018N        Y2019  Y2019F Y2019N
# 0        NaN     389.6563      Fc    NaN
# 2        NaN   10910.3754      Fc    NaN
# 4        NaN   10910.3754      Fc    NaN
# 6        NaN      26.1252      Fc    NaN
# 8        NaN       0.3654      Fc    NaN
# ...      ...          ...     ...    ...
# 35209    NaN       1.0574      Fc    NaN
# 35210    NaN  209078.1221      Fc    NaN
# 35211    NaN     324.2807      Fc    NaN
# 35212    NaN     280.2209      Fc    NaN
# 35213    NaN  209682.6237      Fc    NaN
#
# [30188 rows x 186 columns]

# %%
#drop Source and Source Code as there is only two types & its not relevant for our analysis
emissions_data_df=emissions_data_df.drop(['Source'],axis=1)
df1=emissions_data_df.drop(['Source Code'],axis=1)

# %%
#Check the data frame
df1.head()
# Out:
#    Area Code         Area  Item Code                  Item  Element Code  \
# 0          2  Afghanistan       5058  Enteric Fermentation          7225
# 2          2  Afghanistan       5058  Enteric Fermentation        724413
# 4          2  Afghanistan       5058  Enteric Fermentation        723113
# 6          2  Afghanistan       5059     Manure Management          7225
# 8          2  Afghanistan       5059     Manure Management          7230
#
#                             Element        Unit      Y1961 Y1961F  Y1961N  \
# 0                   Emissions (CH4)  kilotonnes   240.6831     Fc     NaN
# 2  Emissions (CO2eq) from CH4 (AR5)  kilotonnes  6739.1279     Fc     NaN
# 4           Emissions (CO2eq) (AR5)  kilotonnes  6739.1279     Fc     NaN
# 6                   Emissions (CH4)  kilotonnes    11.6228     Fc     NaN
# 8                   Emissions (N2O)  kilotonnes     0.3992     Fc     NaN
#
#    ...  Y2016N       Y2017  Y2017F  Y2017N       Y2018  Y2018F  Y2018N  \
# 0  ...     NaN    371.2863      Fc     NaN    378.8870      Fc     NaN
# 2  ...     NaN  10396.0163      Fc     NaN  10608.8357      Fc     NaN
# 4  ...     NaN  10396.0163      Fc     NaN  10608.8357      Fc     NaN
# 6  ...     NaN     23.7001      Fc     NaN     24.2499      Fc     NaN
# 8  ...     NaN      0.4013      Fc     NaN      0.4074      Fc     NaN
#
#         Y2019  Y2019F  Y2019N
# 0    389.6563      Fc     NaN
# 2  10910.3754      Fc     NaN
# 4  10910.3754      Fc     NaN
# 6     26.1252      Fc     NaN
# 8      0.3654      Fc     NaN
#
# [5 rows x 184 columns]

# %%
#Display the unit value
unit=df1['Unit'].unique()
unit
# Out:
# array(['kilotonnes'], dtype=object)

# %%
#Drop the column 'Unit'
df2=df1.drop(['Unit'],axis=1)

# %%
df2.head()
# Out:
#    Area Code         Area  Item Code                  Item  Element Code  \
# 0          2  Afghanistan       5058  Enteric Fermentation          7225
# 2          2  Afghanistan       5058  Enteric Fermentation        724413
# 4          2  Afghanistan       5058  Enteric Fermentation        723113
# 6          2  Afghanistan       5059     Manure Management          7225
# 8          2  Afghanistan       5059     Manure Management          7230
#
#                             Element      Y1961 Y1961F  Y1961N      Y1962  ...  \
# 0                   Emissions (CH4)   240.6831     Fc     NaN   245.3106  ...
# 2  Emissions (CO2eq) from CH4 (AR5)  6739.1279     Fc     NaN  6868.6971  ...
# 4           Emissions (CO2eq) (AR5)  6739.1279     Fc     NaN  6868.6971  ...
# 6                   Emissions (CH4)    11.6228     Fc     NaN    11.9632  ...
# 8                   Emissions (N2O)     0.3992     Fc     NaN     0.4039  ...
#
#   Y2016N       Y2017  Y2017F Y2017N       Y2018  Y2018F Y2018N       Y2019  \
# 0    NaN    371.2863      Fc    NaN    378.8870      Fc    NaN    389.6563
# 2    NaN  10396.0163      Fc    NaN  10608.8357      Fc    NaN  10910.3754
# 4    NaN  10396.0163      Fc    NaN  10608.8357      Fc    NaN  10910.3754
# 6    NaN     23.7001      Fc    NaN     24.2499      Fc    NaN     26.1252
# 8    NaN      0.4013      Fc    NaN      0.4074      Fc    NaN      0.3654
#
#    Y2019F Y2019N
# 0      Fc    NaN
# 2      Fc    NaN
# 4      Fc    NaN
# 6      Fc    NaN
# 8      Fc    NaN
#
# [5 rows x 183 columns]

# %%
#Checking the data for the column Y1961F
ar=df2['Y1961F'].unique()
ar
# Out:
# array(['Fc', nan], dtype=object)

# %%
#checking for values in the column 'Y1961N'
df2['Y1961N']
# Out:
# 0       NaN
# 2       NaN
# 4       NaN
# 6       NaN
# 8       NaN
#          ..
# 35209   NaN
# 35210   NaN
# 35211   NaN
# 35212   NaN
# 35213   NaN
# Name: Y1961N, Length: 30188, dtype: float64

# %%
#checking for values in the column 'Y1989'
df2['Y1989']
# Out:
# 0         179.5620
# 2        5027.7360
# 4        5027.7360
# 6           8.6167
# 8           0.3045
#            ...
# 35209          NaN
# 35210          NaN
# 35211          NaN
# 35212          NaN
# 35213          NaN
# Name: Y1989, Length: 30188, dtype: float64

# %%
#checking for values in the column 'Y1990'
df2['Y1990']
# Out:
# 0           178.4682
# 2          4997.1108
# 4          4997.1108
# 6             8.5165
# 8             0.3046
#             ...
# 35209         1.4119
# 35210    306473.8942
# 35211       768.5391
# 35212       374.1567
# 35213    307616.5900
# Name: Y1990, Length: 30188, dtype: float64

# %%
#Assigning df2 to a new data frame
df3=df2
df3.head()
# Out:
#    Area Code         Area  Item Code                  Item  Element Code  \
# 0          2  Afghanistan       5058  Enteric Fermentation          7225
# 2          2  Afghanistan       5058  Enteric Fermentation        724413
# 4          2  Afghanistan       5058  Enteric Fermentation        723113
# 6          2  Afghanistan       5059     Manure Management          7225
# 8          2  Afghanistan       5059     Manure Management          7230
#
#                             Element      Y1961 Y1961F  Y1961N      Y1962  ...  \
# 0                   Emissions (CH4)   240.6831     Fc     NaN   245.3106  ...
# 2  Emissions (CO2eq) from CH4 (AR5)  6739.1279     Fc     NaN  6868.6971  ...
# 4           Emissions (CO2eq) (AR5)  6739.1279     Fc     NaN  6868.6971  ...
# 6                   Emissions (CH4)    11.6228     Fc     NaN    11.9632  ...
# 8                   Emissions (N2O)     0.3992     Fc     NaN     0.4039  ...
#
#   Y2016N       Y2017  Y2017F Y2017N       Y2018  Y2018F Y2018N       Y2019  \
# 0    NaN    371.2863      Fc    NaN    378.8870      Fc    NaN    389.6563
# 2    NaN  10396.0163      Fc    NaN  10608.8357      Fc    NaN  10910.3754
# 4    NaN  10396.0163      Fc    NaN  10608.8357      Fc    NaN  10910.3754
# 6    NaN     23.7001      Fc    NaN     24.2499      Fc    NaN     26.1252
# 8    NaN      0.4013      Fc    NaN      0.4074      Fc    NaN      0.3654
#
#    Y2019F Y2019N
# 0      Fc    NaN
# 2      Fc    NaN
# 4      Fc    NaN
# 6      Fc    NaN
# 8      Fc    NaN
#
# [5 rows x 183 columns]

# %%
#Since there is not much data from 1961 to 1989(Outliers),We can drop those columns
for i in range (1961,2020):
     
    year_flag1 = "Y" + str(i) + "F"
    year_flag2 = "Y" + str(i) + "N"
    df3=df3.drop([year_flag1],axis=1)
    df3=df3.drop([year_flag2],axis=1)
for i in range (1961,1990):
    year_flag3 = "Y" +str(i) 
    df3=df3.drop([year_flag3],axis=1)

# %%
#display the df
df3.head()
# Out:
#    Area Code         Area  Item Code                  Item  Element Code  \
# 0          2  Afghanistan       5058  Enteric Fermentation          7225
# 2          2  Afghanistan       5058  Enteric Fermentation        724413
# 4          2  Afghanistan       5058  Enteric Fermentation        723113
# 6          2  Afghanistan       5059     Manure Management          7225
# 8          2  Afghanistan       5059     Manure Management          7230
#
#                             Element      Y1990      Y1991      Y1992  \
# 0                   Emissions (CH4)   178.4682   187.5500   189.7600
# 2  Emissions (CO2eq) from CH4 (AR5)  4997.1108  5251.4000  5313.2800
# 4           Emissions (CO2eq) (AR5)  4997.1108  5251.4000  5313.2800
# 6                   Emissions (CH4)     8.5165     9.3445     9.6669
# 8                   Emissions (N2O)     0.3046     0.3044     0.2960
#
#        Y1993  ...       Y2010       Y2011       Y2012       Y2013       Y2014  \
# 0   190.8300  ...    401.0680    402.5130    396.9210    393.0930    398.2870
# 2  5343.2400  ...  11229.9040  11270.3640  11113.7880  11006.6040  11152.0360
# 4  5343.2400  ...  11229.9040  11270.3640  11113.7880  11006.6040  11152.0360
# 6     9.8348  ...     26.5669     26.1599     26.0913     26.0859     26.3682
# 8     0.2903  ...      0.3980      0.4177      0.4013      0.3868      0.3932
#
#         Y2015       Y2016       Y2017       Y2018       Y2019
# 0    383.3023    380.8767    371.2863    378.8870    389.6563
# 2  10732.4631  10664.5483  10396.0163  10608.8357  10910.3754
# 4  10732.4631  10664.5483  10396.0163  10608.8357  10910.3754
# 6     24.8209     24.6903     23.7001     24.2499     26.1252
# 8      0.3945      0.3931      0.4013      0.4074      0.3654
#
# [5 rows x 36 columns]

# %%
#Finding the index for the particular column
index1=df3.columns.get_loc("Y1990")
print(index1)

index2=df3.columns.get_loc("Y2019")
print(index2)
# Out:
# 6
# 35

# %%
#Printing the sum of null values
df3.iloc[:,6:36]. isnull().sum()
# Out:
# Y1990    4028
# Y1991    3854
# Y1992    1674
# Y1993    1466
# Y1994    1418
# Y1995    1389
# Y1996    1382
# Y1997    1390
# Y1998    1385
# Y1999    1385
# Y2000    1273
# Y2001    1271
# Y2002    1228
# Y2003    1213
# Y2004    1208
# Y2005    1213
# Y2006    1074
# Y2007    1079
# Y2008    1079
# Y2009    1069
# Y2010    1074
# Y2011    1076
# Y2012     962
# Y2013     957
# Y2014     957
# Y2015     962
# Y2016     962
# Y2017     957
# Y2018     957
# Y2019     957
# dtype: int64

# %%
#Trying to find null values for a particular country
df3.loc[(df3["Area Code"] == 2)]
df3
# Out:
#        Area Code         Area  Item Code                  Item  Element Code  \
# 0              2  Afghanistan       5058  Enteric Fermentation          7225
# 2              2  Afghanistan       5058  Enteric Fermentation        724413
# 4              2  Afghanistan       5058  Enteric Fermentation        723113
# 6              2  Afghanistan       5059     Manure Management          7225
# 8              2  Afghanistan       5059     Manure Management          7230
# ...          ...          ...        ...                   ...           ...
# 35209       5873         OECD       6516       Land Use change          7230
# 35210       5873         OECD       6516       Land Use change          7273
# 35211       5873         OECD       6516       Land Use change        724413
# 35212       5873         OECD       6516       Land Use change        724313
# 35213       5873         OECD       6516       Land Use change        723113
#
#                                 Element        Y1990        Y1991  \
# 0                       Emissions (CH4)     178.4682     187.5500
# 2      Emissions (CO2eq) from CH4 (AR5)    4997.1108    5251.4000
# 4               Emissions (CO2eq) (AR5)    4997.1108    5251.4000
# 6                       Emissions (CH4)       8.5165       9.3445
# 8                       Emissions (N2O)       0.3046       0.3044
# ...                                 ...          ...          ...
# 35209                   Emissions (N2O)       1.4119       1.4119
# 35210                   Emissions (CO2)  306473.8942  306473.8942
# 35211  Emissions (CO2eq) from CH4 (AR5)     768.5391     768.5391
# 35212  Emissions (CO2eq) from N2O (AR5)     374.1567     374.1567
# 35213           Emissions (CO2eq) (AR5)  307616.5900  307616.5900
#
#              Y1992        Y1993  ...        Y2010        Y2011        Y2012  \
# 0         189.7600     190.8300  ...     401.0680     402.5130     396.9210
# 2        5313.2800    5343.2400  ...   11229.9040   11270.3640   11113.7880
# 4        5313.2800    5343.2400  ...   11229.9040   11270.3640   11113.7880
# 6           9.6669       9.8348  ...      26.5669      26.1599      26.0913
# 8           0.2960       0.2903  ...       0.3980       0.4177       0.4013
# ...            ...          ...  ...          ...          ...          ...
# 35209       1.4119       1.4119  ...       0.3298       1.8699       0.5001
# 35210  306473.8942  307152.8342  ...  260435.8387  159202.3883  159202.3883
# 35211     768.5391     768.5391  ...     101.1322     573.4284     153.3618
# 35212     374.1567     374.1567  ...      87.3914     495.5169     132.5246
# 35213  307616.5900  308295.5300  ...  260624.3623  160271.3336  159488.2747
#
#              Y2013        Y2014        Y2015        Y2016        Y2017  \
# 0         393.0930     398.2870     383.3023     380.8767     371.2863
# 2       11006.6040   11152.0360   10732.4631   10664.5483   10396.0163
# 4       11006.6040   11152.0360   10732.4631   10664.5483   10396.0163
# 6          26.0859      26.3682      24.8209      24.6903      23.7001
# 8           0.3868       0.3932       0.3945       0.3931       0.4013
# ...            ...          ...          ...          ...          ...
# 35209       1.4242       0.4180       1.2957       0.8834       0.7522
# 35210  159202.3883  159202.3883  159202.3883  209078.1221  209078.1221
# 35211     436.7699     128.1795     397.3500     270.9106     230.6636
# 35212     377.4261     110.7638     343.3623     234.1021     199.3235
# 35213  160016.5843  159441.3315  159943.1006  209583.1348  209508.1091
#
#              Y2018        Y2019
# 0         378.8870     389.6563
# 2       10608.8357   10910.3754
# 4       10608.8357   10910.3754
# 6          24.2499      26.1252
# 8           0.4074       0.3654
# ...            ...          ...
# 35209       0.9253       1.0574
# 35210  209078.1221  209078.1221
# 35211     283.7454     324.2807
# 35212     245.1931     280.2209
# 35213  209607.0606  209682.6237
#
# [30188 rows x 36 columns]

# %%
# Replacing null values with zeros
df3=df3.fillna(0)
df3
# Out:
#        Area Code         Area  Item Code                  Item  Element Code  \
# 0              2  Afghanistan       5058  Enteric Fermentation          7225
# 2              2  Afghanistan       5058  Enteric Fermentation        724413
# 4              2  Afghanistan       5058  Enteric Fermentation        723113
# 6              2  Afghanistan       5059     Manure Management          7225
# 8              2  Afghanistan       5059     Manure Management          7230
# ...          ...          ...        ...                   ...           ...
# 35209       5873         OECD       6516       Land Use change          7230
# 35210       5873         OECD       6516       Land Use change          7273
# 35211       5873         OECD       6516       Land Use change        724413
# 35212       5873         OECD       6516       Land Use change        724313
# 35213       5873         OECD       6516       Land Use change        723113
#
#                                 Element        Y1990        Y1991  \
# 0                       Emissions (CH4)     178.4682     187.5500
# 2      Emissions (CO2eq) from CH4 (AR5)    4997.1108    5251.4000
# 4               Emissions (CO2eq) (AR5)    4997.1108    5251.4000
# 6                       Emissions (CH4)       8.5165       9.3445
# 8                       Emissions (N2O)       0.3046       0.3044
# ...                                 ...          ...          ...
# 35209                   Emissions (N2O)       1.4119       1.4119
# 35210                   Emissions (CO2)  306473.8942  306473.8942
# 35211  Emissions (CO2eq) from CH4 (AR5)     768.5391     768.5391
# 35212  Emissions (CO2eq) from N2O (AR5)     374.1567     374.1567
# 35213           Emissions (CO2eq) (AR5)  307616.5900  307616.5900
#
#              Y1992        Y1993  ...        Y2010        Y2011        Y2012  \
# 0         189.7600     190.8300  ...     401.0680     402.5130     396.9210
# 2        5313.2800    5343.2400  ...   11229.9040   11270.3640   11113.7880
# 4        5313.2800    5343.2400  ...   11229.9040   11270.3640   11113.7880
# 6           9.6669       9.8348  ...      26.5669      26.1599      26.0913
# 8           0.2960       0.2903  ...       0.3980       0.4177       0.4013
# ...            ...          ...  ...          ...          ...          ...
# 35209       1.4119       1.4119  ...       0.3298       1.8699       0.5001
# 35210  306473.8942  307152.8342  ...  260435.8387  159202.3883  159202.3883
# 35211     768.5391     768.5391  ...     101.1322     573.4284     153.3618
# 35212     374.1567     374.1567  ...      87.3914     495.5169     132.5246
# 35213  307616.5900  308295.5300  ...  260624.3623  160271.3336  159488.2747
#
#              Y2013        Y2014        Y2015        Y2016        Y2017  \
# 0         393.0930     398.2870     383.3023     380.8767     371.2863
# 2       11006.6040   11152.0360   10732.4631   10664.5483   10396.0163
# 4       11006.6040   11152.0360   10732.4631   10664.5483   10396.0163
# 6          26.0859      26.3682      24.8209      24.6903      23.7001
# 8           0.3868       0.3932       0.3945       0.3931       0.4013
# ...            ...          ...          ...          ...          ...
# 35209       1.4242       0.4180       1.2957       0.8834       0.7522
# 35210  159202.3883  159202.3883  159202.3883  209078.1221  209078.1221
# 35211     436.7699     128.1795     397.3500     270.9106     230.6636
# 35212     377.4261     110.7638     343.3623     234.1021     199.3235
# 35213  160016.5843  159441.3315  159943.1006  209583.1348  209508.1091
#
#              Y2018        Y2019
# 0         378.8870     389.6563
# 2       10608.8357   10910.3754
# 4       10608.8357   10910.3754
# 6          24.2499      26.1252
# 8           0.4074       0.3654
# ...            ...          ...
# 35209       0.9253       1.0574
# 35210  209078.1221  209078.1221
# 35211     283.7454     324.2807
# 35212     245.1931     280.2209
# 35213  209607.0606  209682.6237
#
# [30188 rows x 36 columns]

# %%
#Changing the column names to standard form
df3=df3.rename({'Area Code': 'Area_Code', 'Item Code': 'Item_Code','Element Code' : 'Element_Code'}, axis=1)
df3.head()
# Out:
#    Area_Code         Area  Item_Code                  Item  Element_Code  \
# 0          2  Afghanistan       5058  Enteric Fermentation          7225
# 2          2  Afghanistan       5058  Enteric Fermentation        724413
# 4          2  Afghanistan       5058  Enteric Fermentation        723113
# 6          2  Afghanistan       5059     Manure Management          7225
# 8          2  Afghanistan       5059     Manure Management          7230
#
#                             Element      Y1990      Y1991      Y1992  \
# 0                   Emissions (CH4)   178.4682   187.5500   189.7600
# 2  Emissions (CO2eq) from CH4 (AR5)  4997.1108  5251.4000  5313.2800
# 4           Emissions (CO2eq) (AR5)  4997.1108  5251.4000  5313.2800
# 6                   Emissions (CH4)     8.5165     9.3445     9.6669
# 8                   Emissions (N2O)     0.3046     0.3044     0.2960
#
#        Y1993  ...       Y2010       Y2011       Y2012       Y2013       Y2014  \
# 0   190.8300  ...    401.0680    402.5130    396.9210    393.0930    398.2870
# 2  5343.2400  ...  11229.9040  11270.3640  11113.7880  11006.6040  11152.0360
# 4  5343.2400  ...  11229.9040  11270.3640  11113.7880  11006.6040  11152.0360
# 6     9.8348  ...     26.5669     26.1599     26.0913     26.0859     26.3682
# 8     0.2903  ...      0.3980      0.4177      0.4013      0.3868      0.3932
#
#         Y2015       Y2016       Y2017       Y2018       Y2019
# 0    383.3023    380.8767    371.2863    378.8870    389.6563
# 2  10732.4631  10664.5483  10396.0163  10608.8357  10910.3754
# 4  10732.4631  10664.5483  10396.0163  10608.8357  10910.3754
# 6     24.8209     24.6903     23.7001     24.2499     26.1252
# 8      0.3945      0.3931      0.4013      0.4074      0.3654
#
# [5 rows x 36 columns]

# %%
#Saving the clean data to a csv file
df3.to_csv("Emission_Clean_Data.csv",header=True,index=False,mode="w")

# %%
#Normalizing the data(Changing the year colums to rows)
emissions_data_new_df = pd.melt(df3, id_vars=["Area_Code", "Area", "Item_Code", "Item", "Element_Code", "Element"],
                  var_name="Year", value_name="Emission")
emissions_data_new_df.head()
# Out:
#    Area_Code         Area  Item_Code                  Item  Element_Code  \
# 0          2  Afghanistan       5058  Enteric Fermentation          7225
# 1          2  Afghanistan       5058  Enteric Fermentation        724413
# 2          2  Afghanistan       5058  Enteric Fermentation        723113
# 3          2  Afghanistan       5059     Manure Management          7225
# 4          2  Afghanistan       5059     Manure Management          7230
#
#                             Element   Year   Emission
# 0                   Emissions (CH4)  Y1990   178.4682
# 1  Emissions (CO2eq) from CH4 (AR5)  Y1990  4997.1108
# 2           Emissions (CO2eq) (AR5)  Y1990  4997.1108
# 3                   Emissions (CH4)  Y1990     8.5165
# 4                   Emissions (N2O)  Y1990     0.3046

# %%
#Removing the letter "Y" from the year data
emissions_data_new_df['Year']=emissions_data_new_df['Year'].str[1:]
emissions_data_new_df.head()
# Out:
#    Area_Code         Area  Item_Code                  Item  Element_Code  \
# 0          2  Afghanistan       5058  Enteric Fermentation          7225
# 1          2  Afghanistan       5058  Enteric Fermentation        724413
# 2          2  Afghanistan       5058  Enteric Fermentation        723113
# 3          2  Afghanistan       5059     Manure Management          7225
# 4          2  Afghanistan       5059     Manure Management          7230
#
#                             Element  Year   Emission
# 0                   Emissions (CH4)  1990   178.4682
# 1  Emissions (CO2eq) from CH4 (AR5)  1990  4997.1108
# 2           Emissions (CO2eq) (AR5)  1990  4997.1108
# 3                   Emissions (CH4)  1990     8.5165
# 4                   Emissions (N2O)  1990     0.3046

# %%
#Checking the count of normalized data
emissions_data_new_df.count()
# Out:
# Area_Code       905640
# Area            905640
# Item_Code       905640
# Item            905640
# Element_Code    905640
# Element         905640
# Year            905640
# Emission        905640
# dtype: int64

# %%
#Checking the datatypes
emissions_data_new_df.dtypes
# Out:
# Area_Code         int64
# Area             object
# Item_Code         int64
# Item             object
# Element_Code      int64
# Element          object
# Year             object
# Emission        float64
# dtype: object

# %%
# changing the Year data type as int
emissions_data_new_df['Year'] = emissions_data_new_df['Year'].astype(int)

# %%
emissions_data_new_df.dtypes
# Out:
# Area_Code         int64
# Area             object
# Item_Code         int64
# Item             object
# Element_Code      int64
# Element          object
# Year              int32
# Emission        float64
# dtype: object

# %%
#Saving the data frame to a csv file
emissions_data_new_df.to_csv("Emission_Normalized_Data.csv",header=True,index=False,mode="w")

# %%
#Saving the clean Emission data to S3 bucket
filename = 'Emission_Normalized_Data.csv' #csv name we want to have in bucket
bucketname = 'emission-bucket' #S3 bucket name

csv_buffer = StringIO()
emissions_data_new_df.to_csv(csv_buffer)

## specifying the access key and secret key.
client = boto3.client('s3', 
        region_name = 'us-east-2', #need to change here
        aws_access_key_id = 'access key',
        aws_secret_access_key = 'secret key' )

response = client.put_object(
    ACL='private',
    Body=csv_buffer.getvalue(),
    Bucket=bucketname,
    Key=filename
)

# %% [markdown]
# # Population Data Cleaning

# %%
# 1. Create a DataFrame for the Population data
population_data_df=pd.read_csv('Population_Data.csv',low_memory=False)

# %%
#Display df
population_data_df.head()
# Out:
#    Area Code         Area  Item Code                       Item  Element Code  \
# 0          2  Afghanistan       3010  Population - Est. & Proj.           511
# 1          2  Afghanistan       3010  Population - Est. & Proj.           511
# 2          2  Afghanistan       3010  Population - Est. & Proj.           511
# 3          2  Afghanistan       3010  Population - Est. & Proj.           511
# 4          2  Afghanistan       3010  Population - Est. & Proj.           511
#
#                          Element  Year Code  Year          Unit     Value  \
# 0  Total Population - Both sexes       1950  1950  1000 persons  7752.118
# 1  Total Population - Both sexes       1951  1951  1000 persons  7840.156
# 2  Total Population - Both sexes       1952  1952  1000 persons  7935.997
# 3  Total Population - Both sexes       1953  1953  1000 persons  8039.694
# 4  Total Population - Both sexes       1954  1954  1000 persons  8151.317
#
#   Flag  Note
# 0    X   NaN
# 1    X   NaN
# 2    X   NaN
# 3    X   NaN
# 4    X   NaN

# %%
#Finding standard mathematical functions.
population_data_df.describe().T
# Out:
#                  count          mean            std     min        25%  \
# Area Code     160411.0    852.357370    1809.356064     1.0    79.0000
# Item Code     160411.0   3010.000000       0.000000  3010.0  3010.0000
# Element Code  160411.0    526.129960      20.781723   511.0   512.0000
# Year Code     160411.0   2018.628398      40.911927  1950.0  1985.0000
# Year          160411.0   2018.628398      40.911927  1950.0  1985.0000
# Value         160411.0  92479.646150  436584.229823     0.0   462.5945
# Note               0.0           NaN            NaN     NaN        NaN
#
#                    50%         75%           max
# Area Code      150.000    224.0000  5.817000e+03
# Item Code     3010.000   3010.0000  3.010000e+03
# Element Code   513.000    551.0000  5.610000e+02
# Year Code     2017.000   2048.0000  2.100000e+03
# Year          2017.000   2048.0000  2.100000e+03
# Value         4397.008  24867.4155  1.087490e+07
# Note               NaN         NaN           NaN

# %%
#Informations about the columns
population_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160411 entries, 0 to 160410
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Area Code     160411 non-null  int64
#  1   Area          160411 non-null  object
#  2   Item Code     160411 non-null  int64
#  3   Item          160411 non-null  object
#  4   Element Code  160411 non-null  int64
#  5   Element       160411 non-null  object
#  6   Year Code     160411 non-null  int64
#  7   Year          160411 non-null  int64
#  8   Unit          160411 non-null  object
#  9   Value         160411 non-null  float64
#  10  Flag          160411 non-null  object
#  11  Note          0 non-null       float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.7+ MB

# %%
#Displaying column names
population_data_df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Year Code', 'Year', 'Unit', 'Value', 'Flag', 'Note'],
#       dtype='object')

# %%
#Dropping unwanted columns

population_data_df=population_data_df.drop(['Item Code','Item','Year Code','Unit','Flag','Note'],axis=1)
population_data_df.head()
# Out:
#    Area Code         Area  Element Code                        Element  Year  \
# 0          2  Afghanistan           511  Total Population - Both sexes  1950
# 1          2  Afghanistan           511  Total Population - Both sexes  1951
# 2          2  Afghanistan           511  Total Population - Both sexes  1952
# 3          2  Afghanistan           511  Total Population - Both sexes  1953
# 4          2  Afghanistan           511  Total Population - Both sexes  1954
#
#       Value
# 0  7752.118
# 1  7840.156
# 2  7935.997
# 3  8039.694
# 4  8151.317

# %%
#Select data for Total population-Both sexes
new=population_data_df.loc[population_data_df['Element Code'] == 511]

new.head()
# Out:
#    Area Code         Area  Element Code                        Element  Year  \
# 0          2  Afghanistan           511  Total Population - Both sexes  1950
# 1          2  Afghanistan           511  Total Population - Both sexes  1951
# 2          2  Afghanistan           511  Total Population - Both sexes  1952
# 3          2  Afghanistan           511  Total Population - Both sexes  1953
# 4          2  Afghanistan           511  Total Population - Both sexes  1954
#
#       Value
# 0  7752.118
# 1  7840.156
# 2  7935.997
# 3  8039.694
# 4  8151.317

# %%
# select the data from year 1990-2019
clean_df=new[(new["Year"] > 1989) &  (new["Year"]  < 2020)]
clean_df.head()
# Out:
#     Area Code         Area  Element Code                        Element  Year  \
# 40          2  Afghanistan           511  Total Population - Both sexes  1990
# 41          2  Afghanistan           511  Total Population - Both sexes  1991
# 42          2  Afghanistan           511  Total Population - Both sexes  1992
# 43          2  Afghanistan           511  Total Population - Both sexes  1993
# 44          2  Afghanistan           511  Total Population - Both sexes  1994
#
#         Value
# 40  12412.308
# 41  13299.017
# 42  14485.546
# 43  15816.603
# 44  17075.727

# %%
#Checking data for the Area Code = 2
clean_df.loc[clean_df["Area Code"]==2]
# Out:
#     Area Code         Area  Element Code                        Element  Year  \
# 40          2  Afghanistan           511  Total Population - Both sexes  1990
# 41          2  Afghanistan           511  Total Population - Both sexes  1991
# 42          2  Afghanistan           511  Total Population - Both sexes  1992
# 43          2  Afghanistan           511  Total Population - Both sexes  1993
# 44          2  Afghanistan           511  Total Population - Both sexes  1994
# 45          2  Afghanistan           511  Total Population - Both sexes  1995
# 46          2  Afghanistan           511  Total Population - Both sexes  1996
# 47          2  Afghanistan           511  Total Population - Both sexes  1997
# 48          2  Afghanistan           511  Total Population - Both sexes  1998
# 49          2  Afghanistan           511  Total Population - Both sexes  1999
# 50          2  Afghanistan           511  Total Population - Both sexes  2000
# 51          2  Afghanistan           511  Total Population - Both sexes  2001
# 52          2  Afghanistan           511  Total Population - Both sexes  2002
# 53          2  Afghanistan           511  Total Population - Both sexes  2003
# 54          2  Afghanistan           511  Total Population - Both sexes  2004
# 55          2  Afghanistan           511  Total Population - Both sexes  2005
# 56          2  Afghanistan           511  Total Population - Both sexes  2006
# 57          2  Afghanistan           511  Total Population - Both sexes  2007
# 58          2  Afghanistan           511  Total Population - Both sexes  2008
# 59          2  Afghanistan           511  Total Population - Both sexes  2009
# 60          2  Afghanistan           511  Total Population - Both sexes  2010
# 61          2  Afghanistan           511  Total Population - Both sexes  2011
# 62          2  Afghanistan           511  Total Population - Both sexes  2012
# 63          2  Afghanistan           511  Total Population - Both sexes  2013
# 64          2  Afghanistan           511  Total Population - Both sexes  2014
# 65          2  Afghanistan           511  Total Population - Both sexes  2015
# 66          2  Afghanistan           511  Total Population - Both sexes  2016
# 67          2  Afghanistan           511  Total Population - Both sexes  2017
# 68          2  Afghanistan           511  Total Population - Both sexes  2018
# 69          2  Afghanistan           511  Total Population - Both sexes  2019
#
#         Value
# 40  12412.308
# 41  13299.017
# 42  14485.546
# 43  15816.603
# 44  17075.727
# 45  18110.657
# 46  18853.437
# 47  19357.126
# 48  19737.765
# 49  20170.844
# 50  20779.953
# 51  21606.988
# 52  22600.770
# 53  23680.871
# 54  24726.684
# 55  25654.277
# 56  26433.049
# 57  27100.536
# 58  27722.276
# 59  28394.813
# 60  29185.507
# 61  30117.413
# 62  31161.376
# 63  32269.589
# 64  33370.794
# 65  34413.603
# 66  35383.032
# 67  36296.113
# 68  37171.921
# 69  38041.754

# %%
#Drop Element Code and Element as its not needed for our analysis
clean_population_df=clean_df.drop(['Element Code','Element'],axis=1)

clean_population_df.head()
# Out:
#     Area Code         Area  Year      Value
# 40          2  Afghanistan  1990  12412.308
# 41          2  Afghanistan  1991  13299.017
# 42          2  Afghanistan  1992  14485.546
# 43          2  Afghanistan  1993  15816.603
# 44          2  Afghanistan  1994  17075.727

# %%
#Standardising the column names
clean_population_df=clean_population_df.rename({'Area Code': 'Area_Code', 'Value':'Population'}, axis=1)
clean_population_df.head()
# Out:
#     Area_Code         Area  Year  Population
# 40          2  Afghanistan  1990   12412.308
# 41          2  Afghanistan  1991   13299.017
# 42          2  Afghanistan  1992   14485.546
# 43          2  Afghanistan  1993   15816.603
# 44          2  Afghanistan  1994   17075.727

# %%
#Resetting index
clean_population_df.reset_index(inplace=True, drop=True)
clean_population_df
# Out:
#       Area_Code                                     Area  Year   Population
# 0             2                              Afghanistan  1990    12412.308
# 1             2                              Afghanistan  1991    13299.017
# 2             2                              Afghanistan  1992    14485.546
# 3             2                              Afghanistan  1993    15816.603
# 4             2                              Afghanistan  1994    17075.727
# ...         ...                                      ...   ...          ...
# 7925       5817  Net Food Importing Developing Countries  2015  1495081.183
# 7926       5817  Net Food Importing Developing Countries  2016  1527235.522
# 7927       5817  Net Food Importing Developing Countries  2017  1559721.436
# 7928       5817  Net Food Importing Developing Countries  2018  1592589.456
# 7929       5817  Net Food Importing Developing Countries  2019  1625925.224
#
# [7930 rows x 4 columns]

# %%
#clean population df is saved as csv
clean_population_df.to_csv("Population_Clean_Data.csv",header=True,index=False,mode="w")
clean_population_df.reset_index(drop=True, inplace=True)

clean_population_df.head()
# Out:
#    Area_Code         Area  Year  Population
# 0          2  Afghanistan  1990   12412.308
# 1          2  Afghanistan  1991   13299.017
# 2          2  Afghanistan  1992   14485.546
# 3          2  Afghanistan  1993   15816.603
# 4          2  Afghanistan  1994   17075.727

# %%
filename = 'Population_Clean_Data.csv' #Any name we want to have in bucket
bucketname = 'emission-bucket' #S3 bucket name

csv_buffer = StringIO()
clean_population_df.to_csv(csv_buffer)

## in AWS to go click ur name and then "My Security Credentials". Then "Access Keys"
client = boto3.client('s3', 
        region_name = 'us-east-2', #need to change here
        aws_access_key_id = 'access key',
        aws_secret_access_key = 'secret key' )

response = client.put_object(
    ACL='private',
    Body=csv_buffer.getvalue(),
    Bucket=bucketname,
    Key=filename
)
